# %% [markdown]
# <a href="https://colab.research.google.com/github/ritik619/ML_using_TensorFlow/blob/master/regression_autombile_mileage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.0.0-beta1
from __future__ import absolute_import, division, print_function, unicode_literals

import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)

# %%
# !pip install -q seaborn

# %% [markdown]
# this dataset_path is the location where we save auto-mpg.data

# %%
dataset_path = keras.utils.get_file("auto-mpg.data" , "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")
dataset_path
print(dataset_path)
# Out:
# /root/.keras/datasets/auto-mpg.data

# %%
column_names = ['MPG','Cylinders','Displacement','Horsepower','Weight',
                'Acceleration', 'Model Year', 'Origin']
raw_dataset = pd.read_csv(dataset_path, names=column_names,
                      na_values = "?", comment='\t',
                      sep=" ", skipinitialspace=True)
dataset = raw_dataset.copy()
dataset.head( )
# Out:
#     MPG  Cylinders  Displacement  ...  Acceleration  Model Year  Origin
# 0  18.0          8         307.0  ...          12.0          70       1
# 1  15.0          8         350.0  ...          11.5          70       1
# 2  18.0          8         318.0  ...          11.0          70       1
# 3  16.0          8         304.0  ...          12.0          70       1
# 4  17.0          8         302.0  ...          10.5          70       1
#
# [5 rows x 8 columns]

# %%
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
dataset = dataset.dropna()

# %%
origin = dataset.pop('Origin')

# %%
dataset[ 'USA'    ] = ( origin == 1)*1.0
dataset[ 'Europe' ] = ( origin == 2)*1.0
dataset[ 'Japan'  ] = ( origin == 3)*1.0

# %%
dataset.tail(4)

# %%
train_dataset = dataset.sample(frac=0.8,random_state= 0)
test_dataset = dataset.drop(train_dataset.index)

# %%
sns.pairplot(train_dataset[["MPG", "Cylinders", "Displacement", "Weight"]], diag_kind="kde")
plt.show()
# used to find similairty b/w pairs

# %%
train_stats = train_dataset.describe()
train_stats.pop("MPG")
train_stats = train_stats.transpose()
train_statst
# Out:
#               count         mean         std  ...     50%      75%     max
# Cylinders     314.0     5.477707    1.699788  ...     4.0     8.00     8.0
# Displacement  314.0   195.318471  104.331589  ...   151.0   265.75   455.0
# Horsepower    314.0   104.869427   38.096214  ...    94.5   128.00   225.0
# Weight        314.0  2990.251592  843.898596  ...  2822.5  3608.00  5140.0
# Acceleration  314.0    15.559236    2.789230  ...    15.5    17.20    24.8
# Model Year    314.0    75.898089    3.675642  ...    76.0    79.00    82.0
# USA           314.0     0.624204    0.485101  ...     1.0     1.00     1.0
# Europe        314.0     0.178344    0.383413  ...     0.0     0.00     1.0
# Japan         314.0     0.197452    0.398712  ...     0.0     0.00     1.0
#
# [9 rows x 8 columns]

# %%
train_labels = train_dataset.pop('MPG')
test_labels  = test_dataset.pop('MPG')

# %%
def norm(x):
  normx = (x-train_stats['mean'])/ train_stats['std']
  return normx
ntrain_data = norm(train_dataset)
ntest_data  = norm(test_dataset) 

ntrain_data.head(4)
# Out:
#      Cylinders  Displacement  Horsepower  ...       USA    Europe     Japan
# 146  -0.869348     -1.009459   -0.784052  ...  0.774676 -0.465148 -0.495225
# 282  -0.869348     -0.530218   -0.442811  ...  0.774676 -0.465148 -0.495225
# 69    1.483887      1.482595    1.447140  ...  0.774676 -0.465148 -0.495225
# 378  -0.869348     -0.865687   -1.099044  ...  0.774676 -0.465148 -0.495225
#
# [4 rows x 9 columns]

# %%
def new_model():
  model= keras.Sequential([
      layers.Dense(64,activation = tf.nn.relu, input_shape = [len(train_dataset.keys())]),
      layers.Dense(64,activation = tf.nn.relu),
      layes.Dense(1)])
  optimizer = tf.keras.optimizers.RMSprop(0.001)
  model.compile(loss="mean_squared_error",
                optimzer=optimizer,
                metrics=['mean_absolute_error','mean_squared_error'])
  return model

# %%
model = new_model()
model.fit(ntrain_data,train_labels,epochs = )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-ce90fca44bd4> in <module>()
# ----> 1 model = new_model()
#       2 model.fir
#
# <ipython-input-73-720f4f559368> in new_model()
#       3       layers.Dense(64,activation = tf.nn.relu, input_shape = [len(train_dataset.keys())]),
#       4       layers.Dense(64,activation = tf.nn.relu),
# ----> 5       layes.Dense(1)])
#       6   optimizer = tf.keras.optimizers.RMSprop(0.001)
#       7   model.compile(loss="mean_squared_error",
#
# NameError: name 'layes' is not defined
